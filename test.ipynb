# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
from components.data_import import fetch_exchange_rates
from components.data_cleaning import clean_fx_data
from components.logger import get_logger
from components.data_load import load_to_bigquery

# %%
data=fetch_exchange_rates(start_date="2026-04-26",end_date="2026-04-29")
# Out:
# Fetched 616 rows: 2026-04-26 → 2026-04-29
# Total rows fetched: 616

# %%
pkl_path = clean_fx_data(data, output_path="fx_cleaned_data.pkl")
# Out:
# Cleaned data saved to 'fx_cleaned_data.pkl' — shape: (616, 8)

# %%
load_to_bigquery(pkl_path)
# Out:
# 2026-05-01 19:02:32  INFO  components.data_load  Starting BigQuery load — project: fx-project-490400
# 2026-05-01 19:02:32  INFO  components.data_load  BigQuery client initialised.
# 2026-05-01 19:02:33  INFO  components.data_load  Dataset 'fx_rates' already exists — skipping creation.
# 2026-05-01 19:02:33  INFO  components.data_load  Table 'exchange_rates' already exists — skipping creation.
# 2026-05-01 19:02:33  INFO  components.data_load  Reading pickle file from 'fx_cleaned_data.pkl'...
# 2026-05-01 19:02:33  INFO  components.data_load  Loaded 616 rows from pickle.
# 2026-05-01 19:02:33  INFO  components.data_load  Loading data into 'fx-project-490400.fx_rates.exchange_rates'...
# /Users/dhruvimodi/Desktop/project/fx_analysis/venv/lib/python3.14/site-packages/google/cloud/bigquery/_pandas_helpers.py:486: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# 2026-05-01 19:02:37  INFO  components.data_load  Load complete. Total rows now in table: 74445
